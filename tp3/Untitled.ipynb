# %%
import pandas as pd

tab = pd.read_csv("UCI_Credit_Card.csv")

# %%
data_history = tab[:int(len(tab)*0.80)]

# %%
data_test = tab[int(len(tab)*0.80):]

# %%
data_test["target"].sum()
# Out:
# np.int64(1266)

# %%
test_competition = data_test.drop(columns=["target"])

# %%
data_history.to_csv("data_history.csv" , index = False)

# %%
data_test.to_csv("data_test.csv" , index = False)

# %%
test_competition.to_csv("test_competition.csv" , index = False)

# %%
data_test[["ID" , "target"]].to_csv("data_test.csv" , index = False)
